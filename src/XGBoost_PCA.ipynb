# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import optuna
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import joblib
from utils import calculate_metric

# %%
# Set up paths and load data
DATA_FOLDER = "../data"
TRAIN_FEATURES = DATA_FOLDER + '/train_features2.xlsx'
TRAIN_LABELS = DATA_FOLDER + "/train_labels2.xlsx"
TEST_FEATURES = DATA_FOLDER + "/test_features2.xlsx"
TEST_LABELS = DATA_FOLDER + "/test_labels2.xlsx"
OUTPUT_PATH = '../output/xgboost_pca'

# Create output directory if it doesn't exist
output_dir = Path(OUTPUT_PATH)
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# Load data
train_features = pd.read_excel(TRAIN_FEATURES)
train_labels = pd.read_excel(TRAIN_LABELS)
test_features = pd.read_excel(TEST_FEATURES)
test_labels = pd.read_excel(TEST_LABELS)

print("Training features shape:", train_features.shape)
print("Test features shape:", test_features.shape)
# Out:
# Training features shape: (1293, 317)
# Test features shape: (432, 317)

# %%
def create_pca_pipeline(n_components=100):
    """
    Create a pipeline with StandardScaler and PCA
    n_components: float between 0 and 1 (explained variance ratio)
    """
    return Pipeline([
        ('scaler', StandardScaler()),
        ('pca', PCA(n_components=n_components))
    ])

# Separate numerical and categorical features
numerical_features = train_features.select_dtypes(include=['int64', 'float64']).columns
categorical_features = train_features.select_dtypes(include=['object', 'bool']).columns

# Create preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', create_pca_pipeline(), numerical_features),
        ('cat', 'passthrough', categorical_features)
    ])

# %%
def objective(trial):
    param = {
        # "verbosity": 0,
        "objective": "reg:squarederror",
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, log=True),
        # defines booster, gblinear for linear functions.
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        # L2 regularization weight.
        # "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        # L1 regularization weight.
        # "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
    }
    
    if param["booster"] in "gbtree":
        # sampling according to each tree.
        param["colsample_bytree"] = trial.suggest_float("colsample_bytree", 0.2, 1.0)
        # sampling ratio for training data.
        param["subsample"] = trial.suggest_float("subsample", 0.2, 1.0)
        # use exact for small dataset.
        param["tree_method"] = trial.suggest_categorical("tree_method", ["exact", "auto"])

    if param["booster"] in ["gbtree", "dart"]:
        # maximum depth of the tree, signifies complexity of the tree.
        param["max_depth"] = trial.suggest_int("max_depth", 2, 28, step=2)
        # minimum child weight, larger the term more conservative the tree.
        # param["min_child_weight"] = trial.suggest_int("min_child_weight", 1, 10)
        param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
        # defines how selective algorithm is.
        # param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        # param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)
    
    model = xgb.XGBRegressor(**param, random_state=42)
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    score = -cross_val_score(
        pipeline, train_features, train_labels.values.ravel(),
        cv=5, scoring='neg_root_mean_squared_error'
    ).mean()
    
    return score

# %%
# Run hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Get best parameters
best_params = study.best_params
print("Best parameters:", best_params)
# Out:
# [I 2025-04-14 11:02:57,525] A new study created in memory with name: no-name-24aac3eb-9d71-4b3d-bdf9-fcfbc97687fe
# [I 2025-04-14 11:04:14,982] Trial 0 finished with value: 0.27348939053418764 and parameters: {'n_estimators': 189, 'booster': 'gbtree', 'colsample_bytree': 0.5951706805093191, 'subsample': 0.5171638635986554, 'tree_method': 'auto', 'max_depth': 2, 'eta': 0.021677723770513198}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:05:42,277] Trial 1 finished with value: 0.3334537011308575 and parameters: {'n_estimators': 137, 'booster': 'gblinear'}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:07:06,260] Trial 2 finished with value: 0.33804441293642445 and parameters: {'n_estimators': 104, 'booster': 'gblinear'}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:09:41,528] Trial 3 finished with value: 0.32778398612228815 and parameters: {'n_estimators': 113, 'booster': 'dart', 'max_depth': 8, 'eta': 9.183532752281618e-05, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 4.676290030905557e-05, 'skip_drop': 3.296924256642764e-05}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:14:55,981] Trial 4 finished with value: 0.3293013415849459 and parameters: {'n_estimators': 625, 'booster': 'gbtree', 'colsample_bytree': 0.9914766987795793, 'subsample': 0.8099841524066484, 'tree_method': 'auto', 'max_depth': 22, 'eta': 1.886744771217086e-08}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:15:54,818] Trial 5 finished with value: 0.331871601733358 and parameters: {'n_estimators': 173, 'booster': 'gblinear'}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:41:28,109] Trial 6 finished with value: 0.3277550555489289 and parameters: {'n_estimators': 512, 'booster': 'dart', 'max_depth': 14, 'eta': 1.8724755328724448e-05, 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.04974990725321227, 'skip_drop': 0.00018713055955321578}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 11:42:56,240] Trial 7 finished with value: 0.32395245847340315 and parameters: {'n_estimators': 403, 'booster': 'gblinear'}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 12:16:49,639] Trial 8 finished with value: 0.32927273377581084 and parameters: {'n_estimators': 768, 'booster': 'dart', 'max_depth': 24, 'eta': 6.719752562058859e-07, 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.035641671517368696, 'skip_drop': 0.19135173822310875}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 12:17:29,604] Trial 9 finished with value: 0.32930134060806826 and parameters: {'n_estimators': 155, 'booster': 'gbtree', 'colsample_bytree': 0.3020618316127661, 'subsample': 0.31166443136649397, 'tree_method': 'auto', 'max_depth': 26, 'eta': 2.8860349093006627e-08}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 12:18:00,625] Trial 10 finished with value: 0.2821284646005903 and parameters: {'n_estimators': 258, 'booster': 'gbtree', 'colsample_bytree': 0.6360080339875812, 'subsample': 0.4505594602003214, 'tree_method': 'exact', 'max_depth': 2, 'eta': 0.4269161400626404}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 12:18:40,532] Trial 11 finished with value: 0.32612240880107024 and parameters: {'n_estimators': 260, 'booster': 'gbtree', 'colsample_bytree': 0.6031040729091158, 'subsample': 0.4617963634497021, 'tree_method': 'exact', 'max_depth': 4, 'eta': 0.6027280859634164}. Best is trial 0 with value: 0.27348939053418764.
# [I 2025-04-14 12:19:10,837] Trial 12 finished with value: 0.25606581001347706 and parameters: {'n_estimators': 251, 'booster': 'gbtree', 'colsample_bytree': 0.6210574933916008, 'subsample': 0.6010206968287006, 'tree_method': 'exact', 'max_depth': 2, 'eta': 0.18318760870303252}. Best is trial 12 with value: 0.25606581001347706.
# [I 2025-04-14 12:19:45,836] Trial 13 finished with value: 0.2412376577013129 and parameters: {'n_estimators': 220, 'booster': 'gbtree', 'colsample_bytree': 0.7153463678291216, 'subsample': 0.7034424468277939, 'tree_method': 'exact', 'max_depth': 10, 'eta': 0.01214634497504036}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 12:20:30,823] Trial 14 finished with value: 0.24407731299802604 and parameters: {'n_estimators': 296, 'booster': 'gbtree', 'colsample_bytree': 0.8016180016638736, 'subsample': 0.7713720988122869, 'tree_method': 'exact', 'max_depth': 12, 'eta': 0.005413440584439433}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 12:21:31,130] Trial 15 finished with value: 0.2561824690420786 and parameters: {'n_estimators': 376, 'booster': 'gbtree', 'colsample_bytree': 0.8655651782742405, 'subsample': 0.8534376821607924, 'tree_method': 'exact', 'max_depth': 14, 'eta': 0.0024495334710909894}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 12:22:12,698] Trial 16 finished with value: 0.27855506838438626 and parameters: {'n_estimators': 329, 'booster': 'gbtree', 'colsample_bytree': 0.8071592952794364, 'subsample': 0.6986060245526495, 'tree_method': 'exact', 'max_depth': 8, 'eta': 0.0017026373611670018}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 12:22:59,136] Trial 17 finished with value: 0.2677835011428945 and parameters: {'n_estimators': 203, 'booster': 'gbtree', 'colsample_bytree': 0.8075582562991271, 'subsample': 0.9735787405175549, 'tree_method': 'exact', 'max_depth': 18, 'eta': 0.0031140685241413312}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 12:23:44,453] Trial 18 finished with value: 0.24245560238744743 and parameters: {'n_estimators': 456, 'booster': 'gbtree', 'colsample_bytree': 0.38353279435712806, 'subsample': 0.7150499986166621, 'tree_method': 'exact', 'max_depth': 10, 'eta': 0.00962867515575726}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:42:14,151] Trial 19 finished with value: 0.3124446009403875 and parameters: {'n_estimators': 969, 'booster': 'dart', 'max_depth': 8, 'eta': 0.00012773972599929343, 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 1.4400539952341648e-08, 'skip_drop': 7.987227487715228e-08}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:44:16,883] Trial 20 finished with value: 0.24493196341314558 and parameters: {'n_estimators': 454, 'booster': 'gbtree', 'colsample_bytree': 0.3328653853118359, 'subsample': 0.6472667979254473, 'tree_method': 'exact', 'max_depth': 18, 'eta': 0.037156296984874035}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:46:23,997] Trial 21 finished with value: 0.2426071049317801 and parameters: {'n_estimators': 313, 'booster': 'gbtree', 'colsample_bytree': 0.450368328792176, 'subsample': 0.7614409946140197, 'tree_method': 'exact', 'max_depth': 12, 'eta': 0.017206582402531704}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:48:46,951] Trial 22 finished with value: 0.3108306827779981 and parameters: {'n_estimators': 539, 'booster': 'gbtree', 'colsample_bytree': 0.4441677151593002, 'subsample': 0.9047231708533927, 'tree_method': 'exact', 'max_depth': 10, 'eta': 0.00027545119335139237}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:51:04,806] Trial 23 finished with value: 0.24563738945085203 and parameters: {'n_estimators': 342, 'booster': 'gbtree', 'colsample_bytree': 0.4508675925410931, 'subsample': 0.7103574695277854, 'tree_method': 'exact', 'max_depth': 18, 'eta': 0.04134670922647403}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:52:41,188] Trial 24 finished with value: 0.31764567784771514 and parameters: {'n_estimators': 220, 'booster': 'gbtree', 'colsample_bytree': 0.42715211111456935, 'subsample': 0.7396897663775722, 'tree_method': 'exact', 'max_depth': 6, 'eta': 0.00058716672003734}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:54:47,806] Trial 25 finished with value: 0.24225883341737972 and parameters: {'n_estimators': 624, 'booster': 'gbtree', 'colsample_bytree': 0.23642695461089572, 'subsample': 0.5711903698428175, 'tree_method': 'exact', 'max_depth': 12, 'eta': 0.015591759145917945}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 13:57:46,137] Trial 26 finished with value: 0.3275703186104223 and parameters: {'n_estimators': 686, 'booster': 'gbtree', 'colsample_bytree': 0.20711481261668044, 'subsample': 0.5852991042545177, 'tree_method': 'auto', 'max_depth': 10, 'eta': 2.416093360620722e-05}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 14:00:01,894] Trial 27 finished with value: 0.24699161541412154 and parameters: {'n_estimators': 939, 'booster': 'gbtree', 'colsample_bytree': 0.20892102165911414, 'subsample': 0.36821822084494704, 'tree_method': 'exact', 'max_depth': 16, 'eta': 0.10786998860212148}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 14:18:46,509] Trial 28 finished with value: 0.25299774603389796 and parameters: {'n_estimators': 446, 'booster': 'dart', 'max_depth': 12, 'eta': 0.007809794894879231, 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.4813466878726395e-08, 'skip_drop': 0.303468950222604}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 14:19:11,965] Trial 29 finished with value: 0.3235684895040234 and parameters: {'n_estimators': 570, 'booster': 'gblinear'}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 14:19:44,555] Trial 30 finished with value: 0.26025090780052385 and parameters: {'n_estimators': 761, 'booster': 'gbtree', 'colsample_bytree': 0.3490597615214069, 'subsample': 0.2169953127762993, 'tree_method': 'exact', 'max_depth': 6, 'eta': 0.10773265994013967}. Best is trial 13 with value: 0.2412376577013129.
# [I 2025-04-14 14:20:29,961] Trial 31 finished with value: 0.2407650557227831 and parameters: {'n_estimators': 293, 'booster': 'gbtree', 'colsample_bytree': 0.5343004529208513, 'subsample': 0.6450299620605517, 'tree_method': 'exact', 'max_depth': 12, 'eta': 0.014062459219759479}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:21:14,960] Trial 32 finished with value: 0.2886930047449181 and parameters: {'n_estimators': 462, 'booster': 'gbtree', 'colsample_bytree': 0.5280633054909896, 'subsample': 0.6294086416748054, 'tree_method': 'exact', 'max_depth': 10, 'eta': 0.000902221232630422}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:21:53,210] Trial 33 finished with value: 0.24696898798895933 and parameters: {'n_estimators': 222, 'booster': 'gbtree', 'colsample_bytree': 0.711546279903109, 'subsample': 0.5488670746217739, 'tree_method': 'exact', 'max_depth': 16, 'eta': 0.007352495298158792}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:22:16,463] Trial 34 finished with value: 0.3348312926442085 and parameters: {'n_estimators': 130, 'booster': 'gblinear'}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:23:03,692] Trial 35 finished with value: 0.24366282323708582 and parameters: {'n_estimators': 393, 'booster': 'gbtree', 'colsample_bytree': 0.5363756389396565, 'subsample': 0.6698651654611989, 'tree_method': 'exact', 'max_depth': 12, 'eta': 0.05787381621398204}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:23:31,383] Trial 36 finished with value: 0.24488051218384413 and parameters: {'n_estimators': 290, 'booster': 'gbtree', 'colsample_bytree': 0.27448730956478506, 'subsample': 0.5216493512545648, 'tree_method': 'exact', 'max_depth': 6, 'eta': 0.01635039817734717}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:23:53,613] Trial 37 finished with value: 0.3313739886946388 and parameters: {'n_estimators': 163, 'booster': 'gblinear'}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:44:35,274] Trial 38 finished with value: 0.2552224727576892 and parameters: {'n_estimators': 603, 'booster': 'dart', 'max_depth': 14, 'eta': 0.2433948366315058, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 1.5183668422251543e-05, 'skip_drop': 1.6722136419759296e-08}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:46:45,440] Trial 39 finished with value: 0.326396874561755 and parameters: {'n_estimators': 504, 'booster': 'gbtree', 'colsample_bytree': 0.704182069201422, 'subsample': 0.8409328006104704, 'tree_method': 'exact', 'max_depth': 10, 'eta': 0.9649526219213159}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:48:24,805] Trial 40 finished with value: 0.2417176299392895 and parameters: {'n_estimators': 187, 'booster': 'gbtree', 'colsample_bytree': 0.3812806120450474, 'subsample': 0.6626152700734932, 'tree_method': 'auto', 'max_depth': 8, 'eta': 0.018106819561480653}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:49:53,323] Trial 41 finished with value: 0.2433124271311689 and parameters: {'n_estimators': 184, 'booster': 'gbtree', 'colsample_bytree': 0.3800864485624298, 'subsample': 0.670810298546884, 'tree_method': 'auto', 'max_depth': 8, 'eta': 0.01570121210569131}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:51:19,878] Trial 42 finished with value: 0.31360250167116593 and parameters: {'n_estimators': 208, 'booster': 'gbtree', 'colsample_bytree': 0.2589650057815086, 'subsample': 0.5904537252559975, 'tree_method': 'auto', 'max_depth': 10, 'eta': 0.0007524021342352834}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:53:03,468] Trial 43 finished with value: 0.2514785967422549 and parameters: {'n_estimators': 130, 'booster': 'gbtree', 'colsample_bytree': 0.5177566555184927, 'subsample': 0.7238739827990975, 'tree_method': 'auto', 'max_depth': 12, 'eta': 0.009841447564809511}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:54:11,163] Trial 44 finished with value: 0.24452660842248938 and parameters: {'n_estimators': 241, 'booster': 'gbtree', 'colsample_bytree': 0.40079373337430757, 'subsample': 0.5514846827693682, 'tree_method': 'auto', 'max_depth': 6, 'eta': 0.03800059231841306}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:55:08,590] Trial 45 finished with value: 0.3320679619489556 and parameters: {'n_estimators': 150, 'booster': 'gblinear'}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 14:58:25,420] Trial 46 finished with value: 0.3292233322052603 and parameters: {'n_estimators': 660, 'booster': 'gbtree', 'colsample_bytree': 0.6664275024535254, 'subsample': 0.46297630016162494, 'tree_method': 'auto', 'max_depth': 14, 'eta': 1.0287540694489263e-06}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 15:03:12,598] Trial 47 finished with value: 0.3252812503442629 and parameters: {'n_estimators': 279, 'booster': 'dart', 'max_depth': 4, 'eta': 0.0036483827553851307, 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.6810258277716627, 'skip_drop': 0.00044712081344568957}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 15:04:13,193] Trial 48 finished with value: 0.24530528384203448 and parameters: {'n_estimators': 105, 'booster': 'gbtree', 'colsample_bytree': 0.503280054587623, 'subsample': 0.7869298784618888, 'tree_method': 'auto', 'max_depth': 8, 'eta': 0.09240724231110108}. Best is trial 31 with value: 0.2407650557227831.
# [I 2025-04-14 15:05:23,510] Trial 49 finished with value: 0.32835485772257644 and parameters: {'n_estimators': 190, 'booster': 'gbtree', 'colsample_bytree': 0.31946247699351993, 'subsample': 0.6278857992155576, 'tree_method': 'exact', 'max_depth': 28, 'eta': 4.0443185552096676e-05}. Best is trial 31 with value: 0.2407650557227831.
# Best parameters: {'n_estimators': 293, 'booster': 'gbtree', 'colsample_bytree': 0.5343004529208513, 'subsample': 0.6450299620605517, 'tree_method': 'exact', 'max_depth': 12, 'eta': 0.014062459219759479}

# %%
best_params = {'n_estimators': 353,
 'booster': 'dart',
 'max_depth': 6,
 'eta': 0.046653323948485266,
 'sample_type': 'uniform',
 'normalize_type': 'forest',
 'rate_drop': 4.201145869116434e-06,
 'skip_drop': 0.0013199458257448385}

# %%
# Train final model with best parameters
final_model = xgb.XGBRegressor(**best_params, random_state=42)
final_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', final_model)
])

# Fit the model
final_pipeline.fit(train_features, train_labels.values.ravel())
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=100))]),
#                                                   Index(['coupon rate', 'SP500 MD', 'Average daily 1-year SP500 return',
#        'Ratio to MA', 'US Corporate Bond Yield Spread',
#        'US Corporate Bond Yield Spread(3-5 year)',
#        'US Corporate Bond Yield Spread(5-7 year)',
#        'US Corporate Bond Yield Spr...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=6, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=353, n_jobs=None,
#                               normalize_type='forest', ...))])

# %%
# Make predictions
train_predictions = final_pipeline.predict(train_features)
test_predictions = final_pipeline.predict(test_features)

# Calculate and print metrics
train_metrics = calculate_metric(train_predictions, train_labels.values.ravel())
test_metrics = calculate_metric(test_predictions, test_labels.values.ravel())

print("\nTraining Metrics:")
print(f"MAE: {train_metrics[0]:.4f}")
print(f"MAPE: {train_metrics[1]:.4f}%")
print(f"RMSE: {train_metrics[2]:.4f}")
print(f"R2: {train_metrics[3]:.4f}")

print("\nTest Metrics:")
print(f"MAE: {test_metrics[0]:.4f}")
print(f"MAPE: {test_metrics[1]:.4f}%")
print(f"RMSE: {test_metrics[2]:.4f}")
print(f"R2: {test_metrics[3]:.4f}")
# Out:
# Training Metrics:
# MAE: 0.0203
# MAPE: 202.7964%
# RMSE: 0.0405
# R2: 0.9849
#
# Test Metrics:
# MAE: 0.1345
# MAPE: 275.3021%
# RMSE: 0.2194
# R2: 0.5797

# %%
def plot_feature_importance(model, preprocessor):
    # Get feature names after PCA
    n_components = preprocessor.named_transformers_['num'].named_steps['pca'].n_components_
    pca_features = [f'PC{i+1}' for i in range(n_components)]
    cat_features = list(categorical_features)
    
    # Get feature importance
    importance = model.feature_importances_
    
    # Create DataFrame
    feature_importance = pd.DataFrame({
        'Feature': pca_features + cat_features,
        'Importance': importance
    })
    
    # Sort by importance
    feature_importance = feature_importance.sort_values('Importance', ascending=False)
    
    # Plot
    plt.figure(figsize=(10, 6))
    sns.barplot(data=feature_importance.head(20), x='Importance', y='Feature')
    plt.title('Top 20 Feature Importance')
    plt.tight_layout()
    plt.show()

# Plot feature importance
plot_feature_importance(final_model, preprocessor)

# %%
# Save predictions
predictions_df = pd.DataFrame({
    'Actual': test_labels.values.ravel(),
    'Predicted': test_predictions
})
predictions_df.to_excel(f"{OUTPUT_PATH}/predictions.xlsx", index=False)

# Save model
joblib.dump(final_pipeline, f"{OUTPUT_PATH}/xgboost_pca_model.pkl")
